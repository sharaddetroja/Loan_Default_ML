# %% [markdown]
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
#
# <center><b><h1>Loan default prediction project EDA</b></center>
# <pre>

# %%
import pandas as pd

# %% [markdown]
# ### 1. reading data set and assign df variable

# %%
df = pd.read_csv("Loan_default.csv")
df
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %% [markdown]
# ### 2. display fisrt 30 rows

# %%
df.head(30)
# Out:
#         LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0   I38PQUQS96   56   85994       50587          520              80
# 1   HPSK72WA7R   69   50432      124440          458              15
# 2   C1OZ6DPJ8Y   46   84208      129188          451              26
# 3   V2KKSFM3UN   32   31713       44799          743               0
# 4   EY08JDHTZP   60   20437        9139          633               8
# 5   A9S62RQ7US   25   90298       90448          720              18
# 6   H8GXPAOS71   38  111188      177025          429              80
# 7   0HGZQKJ36W   56  126802      155511          531              67
# 8   1R0N3LGNRJ   36   42053       92357          827              83
# 9   CM9L1GTT2P   40  132784      228510          480             114
# 10  IA35XVH6ZO   28  140466      163781          652              94
# 11  Y8UETC3LSG   28  149227      139759          375              56
# 12  RM6QSRHIYP   41   23265       63527          829              87
# ...

# %% [markdown]
# ### 3. display last 10 rows

# %%
df.tail(10)
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 255337  DSL4O0KAWD   64   73743      140354          300               0
# 255338  6V8S5IUS63   68   21711      168231          352              78
# 255339  O6SWO6CBGB   51   69492      122962          348              66
# 255340  48LOOK4VR1   41   61809      119238          444              34
# 255341  AKXAXQN7PG   40  129890      116119          701              38
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 255337               2          4.12        12      0.24          PhD
# ...

# %% [markdown]
# ### 4. number of observations

# %%
df.shape[0]
# Out:
# 255347

# %% [markdown]
# ### 5. number of columns

# %%
df.shape[1]
# Out:
# 18

# %% [markdown]
# ### 6. names of all columns

# %%
df.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'],
#       dtype='object')

# %% [markdown]
# ### 7. how's the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=255347, step=1)

# %% [markdown]
# ### 8. information of each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %% [markdown]
# ### 9. display only income column

# %%
df['Income']
# Out:
# 0         85994
# 1         50432
# 2         84208
# 3         31713
# 4         20437
#           ...
# 255342    37979
# 255343    51953
# 255344    84820
# 255345    85109
# 255346    22418
# Name: Income, Length: 255347, dtype: int64

# %% [markdown]
# ### 10. diffrent values of education column

# %%
df['Education'].unique()
# Out:
# array(["Bachelor's", "Master's", 'High School', 'PhD'], dtype=object)

# %% [markdown]
# ### 11. educational qualification counts

# %%
df['Education'].value_counts()
# Out:
# Education
# Bachelor's     64366
# High School    63903
# Master's       63541
# PhD            63537
# Name: count, dtype: int64

# %% [markdown]
# ### 12. summarize data frame

# %%
df.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %% [markdown]
# ### 13. summarize all columns

# %%
df.describe(include="all")
# Out:
#             LoanID            Age         Income     LoanAmount  \
# count       255347  255347.000000  255347.000000  255347.000000
# unique      255347            NaN            NaN            NaN
# top     ZTH91CGL0B            NaN            NaN            NaN
# freq             1            NaN            NaN            NaN
# mean           NaN      43.498306   82499.304597  127578.865512
# std            NaN      14.990258   38963.013729   70840.706142
# min            NaN      18.000000   15000.000000    5000.000000
# 25%            NaN      31.000000   48825.500000   66156.000000
# 50%            NaN      43.000000   82466.000000  127556.000000
# 75%            NaN      56.000000  116219.000000  188985.000000
# max            NaN      69.000000  149999.000000  249999.000000
#
#           CreditScore  MonthsEmployed  NumCreditLines   InterestRate  \
# count   255347.000000   255347.000000   255347.000000  255347.000000
# ...

# %% [markdown]
# ### 14. summarize only income column

# %%
df['Income'].describe()
# Out:
# count    255347.000000
# mean      82499.304597
# std       38963.013729
# min       15000.000000
# 25%       48825.500000
# 50%       82466.000000
# 75%      116219.000000
# max      149999.000000
# Name: Income, dtype: float64

# %% [markdown]
# ### 15. mean income of users

# %%
df['Income'].mean()
# Out:
# np.float64(82499.30459727351)

# %% [markdown]
# ### 16. Age with least occurrence

# %%
df['Age'].value_counts().tail()
# Out:
# Age
# 48    4810
# 42    4803
# 60    4772
# 52    4748
# 23    4740
# Name: count, dtype: int64

# %% [markdown]
# ### 17. data type of each columns

# %%
df.dtypes
# Out:
# LoanID             object
# Age                 int64
# Income              int64
# LoanAmount          int64
# CreditScore         int64
# MonthsEmployed      int64
# NumCreditLines      int64
# InterestRate      float64
# LoanTerm            int64
# DTIRatio          float64
# Education          object
# EmploymentType     object
# MaritalStatus      object
# HasMortgage        object
# HasDependents      object
# LoanPurpose        object
# HasCoSigner        object
# Default             int64
# dtype: object

# %% [markdown]
# ### 18. Identify which columns have missing values and how many?

# %%
df.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %% [markdown]
# ### 19. min,max & mean age of users

# %%
df['Age'].min()
# Out:
# 18

# %%
df['Age'].max()
# Out:
# 69

# %%
df['Age'].mean()
# Out:
# np.float64(43.498306226429136)
